# %% [markdown]
# # Data Quality Report
#
# **Purpose:** Validate cleaned data against rules in docs/assumptions.md; summarize completeness/validity/consistency issues found and resolved.
#
# **Phase:** 2 — Data Cleaning & Validation
#
# **Status:** TODO
